# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %%
from os import listdir
from os.path import join
import os
import matplotlib.pyplot as plt
from dipy.core.sphere import disperse_charges, HemiSphere
import numpy as np
import pandas as pd
import cProfile
from tqdm import tqdm
from tqdm.contrib import itertools as tqdm_itertools
from scipy.ndimage import gaussian_filter

SMALL_SIZE = 10
MEDIUM_SIZE = 14
BIGGER_SIZE = 16

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

import sys
sys.path.insert(0,'../st_validate/')
import sta_validate
import sta
import apsym_kmeans
import utils

# %% [markdown]
# ## Make sets of 3 equidistant angles

# %%
angle_pairs = np.load("../outputs/angle_pairs.npy")
# Generate 3 angle sets where for each set, the angles are equidistant from each other
# convert angles to cartesian coordinates
a = utils.sph_to_cart(angle_pairs[:,0], order='ij')
b = utils.sph_to_cart(angle_pairs[:,1], order='ij')
# get the dot product between each pair of vectors
m = np.einsum('...i,...i', a, b)
b[np.argwhere(m < 0).squeeze()] = -b[np.argwhere(m < 0).squeeze()]
m = np.abs(m)
gamma = np.sqrt((1+m - 2*m**2)/((1+m)**2 * (1-m)))
c = (m / (1+m))[:,None] * (a + b) + gamma[:,None] * np.cross(a, b)
# convert back to angles
new_angles = np.stack([np.arccos(c[...,0]), np.arctan2(c[...,2], c[...,1])], axis=-1)

angle_triplets = np.concatenate([angle_pairs, new_angles[:,None]], axis=1)

# np.save('../outputs/angle_triplets.npy', angle_triplets, allow_pickle=True)

# %%
# create a random permutation of angles
rand_perm = np.random.permutation(angles)
angle_pairs = np.stack((angles,rand_perm), axis=1)
# check if there are any pairs with the same angles
same_count = np.sum(np.all(angle_pairs[:,0]==angle_pairs[:,1], axis=1))

if same_count==0:
    # np.save('../3d_angle_pairs.npy', angle_pairs, allow_pickle=True)

# %%
angle_pairs = np.load("/home/brysongray/structure_tensor_validation/angle_pairs.npy", allow_pickle=True)

# %% [markdown]
# ## set parameters for 3D phantoms

# %%
shapes = [(72,72,72), (36,72,72), (24,72,72), (18,72,72), (14,72,72), (12,72,72), (10,72,72), (9,72,72)]
# shapes = [(72,72,72),(24,72,72)]
AI = [d[1]/d[0] for d in shapes]
periods = [7,10,13]
# angles = np.load('../3d_angles.npy')
angles = np.load('../angle_triplets.npy')
noises = np.linspace(0,0.3,10)
# root = '/home/bgray/bmap/fibermetric/st_validation/phantoms_3d_var_noise/'
# root = '/home/bgray/bmap/fibermetric/st_validation/phantoms_3d_3_angles/'
# os.makedirs(root, exist_ok=True)

# %% [markdown]
# ## Make variable noise phantoms

# %%
p = 10
n = (96,96)
d = (n[1]/n[0], 1.0)
x = [np.arange(ni)*di for ni,di in zip(n,d)]
noises = np.linspace(0,0.3,4)

# %%
plt.close("all")

# %%
theta_pair = np.load("../theta_pairs.npy", allow_pickle=True)[0]
images = []
for n in noises:
    images.append(sta_validate.make_phantom(x, theta_pair, p, inverse=False, noise=n))

fig, ax = plt.subplots(1, 4, figsize=(10, 4))
ax = ax.flatten()
for i in range(len(ax)):
    I = images[i]
    ax[i].imshow(I)
    ax[i].set_title(f"{noises[i]:.2f}")
    ax[i].axis("off")
plt.tight_layout()
fig.savefig('../outputs/figures/2d_phantoms_with_noise.png')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
root = "/home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_noise/"
shapes = [(24,72,72)]
for i in tqdm(range(len(shapes))):
    n = shapes[i]
    d = (n[1]/n[0], 1.0, 1.0)
    x = [np.arange(ni)*di for ni,di in zip(n,d)]

    for j,k,n in tqdm_itertools.product(range(len(periods)), range(len(angle_pairs)), range(len(noises))):
            p = periods[j]
            angle_pair = angle_pairs[k]
            noise = noises[n]
            # image = sta_validate.make_phantom(x,[angle], p)
            image = sta_validate.make_phantom(x, angle_pair, p, inverse=False, noise=noise)

            # save image
            name = f'phantom_AI-{d[0]:.2f}_period-{p:02d}_theta-{angle_pair[0,0]:.2f}-{angle_pair[1,0]:.2f}_phi-{angle_pair[0,1]:.2f}-{angle_pair[1,1]:.2f}_noise-{noise:.2f}'
            print(f'saving {root+name}')
            np.savez(join(root,name), image=image, AI=d[0], period=p, angle=angle_pair, noise=noise)
# Out:
# ...
#   0%|          | 0/3000 [00:00<?, ?it/s]
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_noise/phantom_AI-3.00_period-07_theta-0.59-1.93_phi-0.29-2.01_noise-0.00
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_noise/phantom_AI-3.00_period-07_theta-0.59-1.93_phi-0.29-2.01_noise-0.03
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_noise/phantom_AI-3.00_period-07_theta-0.59-1.93_phi-0.29-2.01_noise-0.07
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_noise/phantom_AI-3.00_period-07_theta-0.59-1.93_phi-0.29-2.01_noise-0.10
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_noise/phantom_AI-3.00_period-07_theta-0.59-1.93_phi-0.29-2.01_noise-0.13
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_noise/phantom_AI-3.00_period-07_theta-0.59-1.93_phi-0.29-2.01_noise-0.17
# ...

# %% [markdown]
# ## Make 3-angle 3D Phantoms

# %%
angle_triplets = np.load('../outputs/angle_triplets.npy', allow_pickle=True)

# %%
angle_triplets[0]
# Out:
# array([[ 0.5905425 ,  0.29375494],
#        [ 1.92502945,  2.00874656],
#        [ 1.75629416, -0.04384319]])

# %%
n = shapes[0]
d = (n[1]/n[0], 1.0, 1.0)
x = [np.arange(ni)*di for ni,di in zip(n,d)]
image = sta_validate.make_phantom(x, angle_triplets[0], 7, inverse=False)

# %%
plt.figure()
plt.imshow(image[36])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
phantom_file = "/home/bgray/bmap/fibermetric/st_validation/phantoms_3d_3_angles/phantom_AI-1.00_period-07_theta-0.29-1.10-1.45_phi-2.44-0.16-1.48.npz"
phantom_data = np.load(phantom_file, allow_pickle=True)
image, AI, period, angle = phantom_data['image'], phantom_data['AI'], phantom_data['period'], phantom_data['angle']

# %%
image.shape
# Out:
# (72, 72, 72)

# %%
derivative_sigmas = np.linspace(start=0.15, stop=2.5, num=10)
tensor_sigmas = np.linspace(start=0.0, stop=5.0, num=10)
print(derivative_sigmas)
print(tensor_sigmas)
# Out:
# [0.15       0.41111111 0.67222222 0.93333333 1.19444444 1.45555556
#  1.71666667 1.97777778 2.23888889 2.5       ]
# [0.         0.55555556 1.11111111 1.66666667 2.22222222 2.77777778
#  3.33333333 3.88888889 4.44444444 5.        ]

# %%
error = sta_validate.sta_test(image, derivative_sigma=derivative_sigmas[3], tensor_sigma=tensor_sigmas[1], true_thetas=angle)

# %%
for i in tqdm(range(len(shapes))):
    n = shapes[i]
    d = (n[1]/n[0], 1.0, 1.0)
    x = [np.arange(ni)*di for ni,di in zip(n,d)]

    for j,k in tqdm_itertools.product(range(len(periods)), range(len(angle_triplets))):
            p = periods[j]
            angle_triplet = angle_triplets[k]
            # image = sta_validate.make_phantom(x,[angle], p)
            image = sta_validate.make_phantom(x, angle_triplet, p, inverse=False)

            # save image
            name = f'phantom_AI-{d[0]:.2f}_period-{p:02d}_theta-{angle_triplet[0,0]:.2f}-{angle_triplet[1,0]:.2f}-{angle_triplet[2,0]:.2f}_phi-{angle_triplet[0,1]:.2f}-{angle_triplet[1,1]:.2f}-{angle_triplet[2,1]:.2f}'
            print(f'saving {root+name}')
            np.savez(join(root,name), image=image, AI=d[0], period=p, angle=angle_triplet)
# Out:
# ...
#   0%|          | 0/300 [00:00<?, ?it/s]
# saving /home/bgray/bmap/fibermetric/st_validation/phantoms_3d_3_angles/phantom_AI-1.00_period-07_theta-0.59-1.93-1.76_phi-0.29-2.01--0.04
# saving /home/bgray/bmap/fibermetric/st_validation/phantoms_3d_3_angles/phantom_AI-1.00_period-07_theta-1.87-2.08-2.12_phi-1.62-1.42-1.74
# saving /home/bgray/bmap/fibermetric/st_validation/phantoms_3d_3_angles/phantom_AI-1.00_period-07_theta-1.51-1.84-0.61_phi-1.90-3.11-2.97
# saving /home/bgray/bmap/fibermetric/st_validation/phantoms_3d_3_angles/phantom_AI-1.00_period-07_theta-1.55-0.82-1.27_phi-2.39-2.38-1.70
# saving /home/bgray/bmap/fibermetric/st_validation/phantoms_3d_3_angles/phantom_AI-1.00_period-07_theta-1.68-0.98-2.55_phi-0.44-1.95-2.15
# saving /home/bgray/bmap/fibermetric/st_validation/phantoms_3d_3_angles/phantom_AI-1.00_period-07_theta-1.59-1.09-1.31_phi-1.63-1.70-1.21
# ...

# %% [markdown]
# ## Make Variable Width Phantoms

# %%
theta_pairs = np.load("../angle_pairs.npy")
angle = theta_pairs[2]
n = (72,72,72)
d = (n[1]/n[0], 1.0, 1.0)
x = [np.arange(ni)*di for ni,di in zip(n,d)]
p = 20
widths = np.linspace(1,4.5,8)
images = []
for w in widths:
    image = sta_validate.make_phantom(x, angle, p, width=w, inverse=False)
    images.append(image)

# %%
fig, axes = plt.subplots(1, 4, figsize=(11, 6))
axes = axes.flatten()
for i, j in enumerate([0,2,4,6]):
    axes[i].imshow(images[j][36], cmap='gray')  # Assuming images are 3D and you want to plot the middle slice
    axes[i].set_title(f"{widths[j]}")
    axes[i].axis("off")
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
derivative_sigmas = np.linspace(start=0.15, stop=2.5, num=10)
tensor_sigmas = np.linspace(start=0.0, stop=5, num=10)
print(derivative_sigmas)
print(tensor_sigmas)
# Out:
# [0.15       0.41111111 0.67222222 0.93333333 1.19444444 1.45555556
#  1.71666667 1.97777778 2.23888889 2.5       ]
# [0.         0.55555556 1.11111111 1.66666667 2.22222222 2.77777778
#  3.33333333 3.88888889 4.44444444 5.        ]

# %%
I.shape
# Out:
# (72, 72, 72)

# %%
heatmaps = []
for x in range(len(images)):
    I = images[x]
    errors = []
    for i in range(len(derivative_sigmas)):
        for j in range(len(tensor_sigmas)):
            derivative_sigma = derivative_sigmas[i]
            tensor_sigma = tensor_sigmas[j]
            crop_all = round(max(derivative_sigma,tensor_sigma)*8/3) # two-thirds the radius of the largest kernel
            error = sta_validate.sta_test(I, derivative_sigma, tensor_sigma, true_thetas=angle, crop=crop_all, crop_end=None)
            errors.append(error)
    heatmap = np.array(errors).reshape(10,10)
    heatmaps.append(heatmap)

# %%
fig, axes = plt.subplots(1, 8, figsize=(15,5))
for i, ax in enumerate(axes):
    ax.imshow(heatmaps[i], vmin=0.0, vmax=50.0)  # Assuming images are 3D and you want to plot the middle slice
    ax.axis("off")
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
for h in heatmaps:
    d = h.argmin()//10
    t = h.argmin()%10
    print(derivative_sigmas[d],tensor_sigmas[t])
# Out:
# 1.4555555555555555 0.5555555555555556
# 0.6722222222222223 1.1111111111111112
# 0.6722222222222223 0.5555555555555556
# 0.4111111111111111 0.5555555555555556
# 0.15 0.5555555555555556
# 0.15 0.5555555555555556
# 0.9333333333333335 0.5555555555555556
# 0.15 0.0

# %%
min_sigma_g = [derivative_sigmas[h.argmin()//10] for h in heatmaps]
min_sigma_w = [tensor_sigmas[h.argmin()%10] for h in heatmaps]
min_err = [h.min() for h in heatmaps]

fig, ax = plt.subplots(3,1, figsize=(8,8))

ax[0].plot(min_sigma_g)
yticklabels = [f"{d:.2f}" for d in derivative_sigmas]
xticklabels = [f"{w:.2f}" for w in widths]
ax[0].set_yticks(derivative_sigmas, labels=yticklabels)
ax[0].set_xticks([x for x in range(len(widths))], labels=xticklabels)

ax[1].plot(min_sigma_w)
yticklabels = [f"{t:.2f}" for t in tensor_sigmas]
ax[1].set_yticks(tensor_sigmas, labels=yticklabels)
ax[1].set_xticks([x for x in range(len(widths))], labels=xticklabels)

ax[2].plot(min_err)
ax[2].set_xticks([x for x in range(len(widths))], labels=xticklabels)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
errors = np.array(errors).reshape(10,10)
plt.figure()
plt.imshow(errors, vmin=0, vmax=50)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
errors = np.array(errors).reshape(10,10)
plt.figure()
plt.imshow(errors, vmin=0, vmax=50)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
errors = np.array(errors).reshape(10,10)
plt.figure()
plt.imshow(errors, vmin=0, vmax=50)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
root = '/home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_width/'
os.makedirs(root, exist_ok=True)

theta_pairs = np.load("../angle_pairs.npy")
n = (24,72,72)
d = (n[1]/n[0], 1.0, 1.0)
x = [np.arange(ni)*di for ni,di in zip(n,d)]
p = 20
widths = np.linspace(1,4.5,8)
for j,k in tqdm_itertools.product(range(len(widths)), range(len(theta_pairs))):
        angle = theta_pairs[k]
        width = widths[j]
        image = sta_validate.make_phantom(x, angle, p, width=width, inverse=False)
        # save image
        name = f'phantom_AI-{d[0]:.2f}_period-{p:02d}_theta-{angle[0,0]:.2f}-{angle[1,0]:.2f}_phi-{angle[0,1]:.2f}-{angle[1,1]:.2f}_width-{width:.1f}'
        print(f'saving {root+name}')
        np.savez(join(root,name), image=image, AI=d[0], period=p, angle=angle, width=width)
# Out:
#   0%|          | 0/800 [00:00<?, ?it/s]
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_width/phantom_AI-3.00_period-20_theta-0.59-1.93_phi-0.29-2.01_width-1.0
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_width/phantom_AI-3.00_period-20_theta-1.87-2.08_phi-1.62-1.42_width-1.0
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_width/phantom_AI-3.00_period-20_theta-1.51-1.84_phi-1.90-3.11_width-1.0
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_width/phantom_AI-3.00_period-20_theta-1.55-0.82_phi-2.39-2.38_width-1.0
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_width/phantom_AI-3.00_period-20_theta-1.68-0.98_phi-0.44-1.95_width-1.0
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_width/phantom_AI-3.00_period-20_theta-1.59-1.09_phi-1.63-1.70_width-1.0
# ...

# %% [markdown]
# ## Make Heterogeneous Phantoms

# %%
n = (72, 72, 72)
d = (n[1]/n[0], 1.0, 1.0)
x = [np.arange(ni)*di for ni,di in zip(n,d)]
p = 10 
angles = np.load("../angle_pairs.npy")
angle = angles[0]
mask_fracs = [0.1, 0.3, 0.6, 0.9]
fig, ax = plt.subplots(1, 4)
for i, mask_frac in enumerate(mask_fracs):
    I = sta_validate.make_phantom(x, angle, period=7, mask_frac=mask_frac, inverse=False)
    ax[i].imshow(I[I.shape[0] // 2], vmin=0.0, vmax=I.max())
    ax[i].axis("off")
    ax[i].set_title(f"{int(mask_frac*100)}%")

    # ax[i, 1].imshow(I[:, I.shape[1] // 2], vmin=0.0, vmax=I.max())
    # ax[i, 1].axis("off")
    # ax[i, 1].set_title(f"Mask Fraction: {mask_frac:.1f}")
    # ax[i, 2].imshow(I[:, :, I.shape[2] // 2], vmin=0.0, vmax=I.max())
    # ax[i, 2].axis("off")

plt.tight_layout()
fig.savefig('../outputs/figures/3d_phantoms_mask_fractions.png')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')

# %%
fig, ax = plt.subplots(1,3, figsize=(10,4))

ax[0].imshow(I[I.shape[0]//2], vmin=0.0, vmax=I.max())
ax[1].imshow(I[:, I.shape[1]//2], vmin=0.0, vmax=I.max())
ax[2].imshow(I[:, :, I.shape[2]//2], vmin=0.0, vmax=I.max())

# ax[0].imshow(I.max(0), vmin=0.0, vmax=I.max())
# ax[1].imshow(I.max(1), vmin=0.0, vmax=I.max())
# ax[2].imshow(I.max(2), vmin=0.0, vmax=I.max())

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
n = (24,72,72)
d = (n[1]/n[0], 1.0, 1.0)
x = [np.arange(ni)*di for ni,di in zip(n,d)]
periods = (7,10,13)
angle_pairs = np.load("../angle_pairs.npy")
root = "/home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_mask-frac/"
mask_fracs = np.linspace(0.0, 0.9, 10)
for j,k,n in tqdm_itertools.product(range(len(periods)), range(len(angle_pairs)), range(len(mask_fracs))):
        p = periods[j]
        angle_pair = angle_pairs[k]
        mask_frac = mask_fracs[n]
        # image = sta_validate.make_phantom(x,[angle], p)
        image = sta_validate.make_phantom(x, angle_pair, p, inverse=False, mask_frac=mask_frac)

        # save image
        name = f'phantom_AI-{d[0]:.2f}_period-{p:02d}_theta-{angle_pair[0,0]:.2f}-{angle_pair[1,0]:.2f}_phi-{angle_pair[0,1]:.2f}-{angle_pair[1,1]:.2f}_mask_frac-{mask_frac:.1f}'
        print(f'saving {root+name}')
        np.savez(join(root,name), image=image, AI=d[0], period=p, angle=angle_pair, mask_frac=mask_frac)
# Out:
#   0%|          | 0/3000 [00:00<?, ?it/s]
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_mask-frac/phantom_AI-3.00_period-07_theta-0.59-1.93_phi-0.29-2.01_mask_frac-0.0
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_mask-frac/phantom_AI-3.00_period-07_theta-0.59-1.93_phi-0.29-2.01_mask_frac-0.1
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_mask-frac/phantom_AI-3.00_period-07_theta-0.59-1.93_phi-0.29-2.01_mask_frac-0.2
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_mask-frac/phantom_AI-3.00_period-07_theta-0.59-1.93_phi-0.29-2.01_mask_frac-0.3
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_mask-frac/phantom_AI-3.00_period-07_theta-0.59-1.93_phi-0.29-2.01_mask_frac-0.4
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_3d_var_mask-frac/phantom_AI-3.00_period-07_theta-0.59-1.93_phi-0.29-2.01_mask_frac-0.5
# ...

# %% [markdown]
# ## Make 2D Phantoms

# %%
# shapes = [(96,96), (48,96), (32,96), (24,96), (19,96), (16,96), (14,96), (12,96)]
# shapes = [(96,96), (32,96)]
shapes = [(32,96)]
AI = [d[1]/d[0] for d in shapes]
periods = [7,10,13]
# thetas = np.linspace(0,np.pi/2,100)

root = '/home/brysongray/bmap/fibermetric/st_validation/phantoms_2d_var_noise/'
thetas = np.load('../theta_pairs.npy')
# os.makedirs(root, exist_ok=True)

# %%
theta_pairs = [(a, b) for idx, a in enumerate(thetas) for b in thetas[idx+1:]]
ids = np.random.choice(len(theta_pairs), size=100, replace=False)
theta_pairs = np.array(theta_pairs)[ids]
np.save('../2d_angle_pairs', theta_pairs)

# %% [markdown]
# ## Make variable noise 2D phantoms

# %%
for i in tqdm(range(len(shapes))):
    n = shapes[i]
    d = (n[1]/n[0], 1.0)
    x = [np.arange(ni)*di for ni,di in zip(n,d)]

    for j,k,n in tqdm_itertools.product(range(len(periods)), range(len(thetas)), range(len(noises))):
            p = periods[j]
            angle = theta_pairs[k]
            noise = noises[n]
            # image = sta_validate.make_phantom(x,[angle], p)
            image = sta_validate.make_phantom(x, angle, p, inverse=False, noise=noise)
            # save image
            name = f'phantom_AI-{d[0]:.2f}_period-{p:02d}_theta-{angle[0]:.2f}-{angle[1]:.2f}_noise-{noise:.2f}'
            # print(f'saving {root+name}')
            np.savez(join(root,name), image=image, AI=d[0], period=p, angle=angle, noise=noise)
# Out:
# ...
# 100%|██████████| 1/1 [00:12<00:00, 12.03s/it]

# %% [markdown]
# # Make 3-angle 2D phantoms

# %%
theta_pairs = np.load("../outputs/theta_pairs.npy")
deltas = np.abs(theta_pairs[:,0] - theta_pairs[:,1])
third_angle = theta_pairs.min(axis=1) - deltas
third_angle
theta_triplets = np.concatenate((theta_pairs, third_angle[:,None]), axis=1)
# np.save('../outputs/theta_triplets.npy', theta_triplets, allow_pickle=True)

# %%
theta_triplets = np.load('../outputs/theta_triplets.npy', allow_pickle=True)
n = shapes[0]
d = (n[1]/n[0], 1.0)
x = [np.arange(ni)*di for ni,di in zip(n,d)]
image = sta_validate.make_phantom(x, theta_triplets[8], 13, inverse=False)
plt.figure()
plt.imshow(image)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
error = sta_validate.sta_test(image, derivative_sigma=derivative_sigmas[2], tensor_sigma=tensor_sigmas[2], true_thetas=theta_triplets[7])

# %%
root = '/home/bgray/bmap/fibermetric/st_validation/phantoms_2d_3_angles/'
os.makedirs(root, exist_ok=True)

for i in tqdm(range(len(shapes))):
    n = shapes[i]
    d = (n[1]/n[0], 1.0)
    x = [np.arange(ni)*di for ni,di in zip(n,d)]

    for j,k in tqdm_itertools.product(range(len(periods)), range(len(thetas))):
            p = periods[j]
            angle = theta_triplets[k]
            # image = sta_validate.make_phantom(x,[angle], p)
            image = sta_validate.make_phantom(x, angle, p, inverse=False)
            # save image
            name = f'phantom_AI-{d[0]:.2f}_period-{p:02d}_theta-{angle[0]:.2f}-{angle[1]:.2f}-{angle[2]:.2f}'
            print(f'saving {root+name}')
            np.savez(join(root,name), image=image, AI=d[0], period=p, angle=angle)
# Out:
# ...
#   0%|          | 0/300 [00:00<?, ?it/s]
# saving /home/bgray/bmap/fibermetric/st_validation/phantoms_2d_3_angles/phantom_AI-1.00_period-07_theta-1.03-1.33-1.33
# saving /home/bgray/bmap/fibermetric/st_validation/phantoms_2d_3_angles/phantom_AI-1.00_period-07_theta-0.33-0.78-0.78
# saving /home/bgray/bmap/fibermetric/st_validation/phantoms_2d_3_angles/phantom_AI-1.00_period-07_theta-0.06-0.65-0.65
# saving /home/bgray/bmap/fibermetric/st_validation/phantoms_2d_3_angles/phantom_AI-1.00_period-07_theta-0.30-0.36-0.36
# saving /home/bgray/bmap/fibermetric/st_validation/phantoms_2d_3_angles/phantom_AI-1.00_period-07_theta-0.14-0.98-0.98
# saving /home/bgray/bmap/fibermetric/st_validation/phantoms_2d_3_angles/phantom_AI-1.00_period-07_theta-0.13-0.35-0.35
# saving /home/bgray/bmap/fibermetric/st_validation/phantoms_2d_3_angles/phantom_AI-1.00_period-07_theta-0.73-1.33-1.33
# ...

# %% [markdown]
# ## Make Variable Width Phantoms

# %%
theta_pairs = np.load("../theta_pairs.npy")
angle = theta_pairs[4]
# thetas = np.linspace(0,np.pi/2,100)
# angle = thetas[50][None]
n = (96,96)
d = (n[1]/n[0], 1.0)
x = [np.arange(ni)*di for ni,di in zip(n,d)]
p = 10
widths = np.linspace(1,4.5,8)
images = []
for w in widths:
    images.append(sta_validate.make_phantom(x, angle, period=20, width=w, inverse=False))

# %%
fig, axes = plt.subplots(1, 4, figsize=(10, 4))
axes = axes.flatten()
for i, j in enumerate([0,2,4,6]):
    axes[i].imshow(images[j])  # Assuming images are 3D and you want to plot the middle slice
    axes[i].set_title(f"{widths[j]}")
    axes[i].axis("off")
plt.tight_layout()
fig.savefig('../outputs/figures/2d_phantoms_var_width.png')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
root = '/home/brysongray/bmap/fibermetric/st_validation/phantoms_2d_var_width/'
os.makedirs(root, exist_ok=True)

theta_pairs = np.load("../theta_pairs.npy")
n = (32,96)
d = (n[1]/n[0], 1.0)
x = [np.arange(ni)*di for ni,di in zip(n,d)]
p = 20
widths = np.linspace(1,4.5,8)
for j,k in tqdm_itertools.product(range(len(widths)), range(len(theta_pairs))):
        angle = theta_pairs[k]
        width = widths[j]
        image = sta_validate.make_phantom(x, angle, p, width=width, inverse=False)
        # save image
        name = f'phantom_AI-{d[0]:.2f}_period-{p:02d}_theta-{angle[0]:.2f}-{angle[1]:.2f}_width-{width:.1f}'
        print(f'saving {root+name}')
        np.savez(join(root,name), image=image, AI=d[0], period=p, angle=angle, width=width)
# Out:
#   0%|          | 0/800 [00:00<?, ?it/s]
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_2d_var_width/phantom_AI-3.00_period-20_theta-1.03-1.33_width-1.0
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_2d_var_width/phantom_AI-3.00_period-20_theta-0.33-0.78_width-1.0
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_2d_var_width/phantom_AI-3.00_period-20_theta-0.06-0.65_width-1.0
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_2d_var_width/phantom_AI-3.00_period-20_theta-0.30-0.36_width-1.0
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_2d_var_width/phantom_AI-3.00_period-20_theta-0.14-0.98_width-1.0
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_2d_var_width/phantom_AI-3.00_period-20_theta-0.13-0.35_width-1.0
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_2d_var_width/phantom_AI-3.00_period-20_theta-0.73-1.33_width-1.0
# ...

# %% [markdown]
# ## Make Heterogeneous Phantoms

# %%
n = (96,96)
d = (n[1]/n[0], 1.0)
x = [np.arange(ni)*di for ni,di in zip(n,d)]
p = 10 
angles = np.load("../theta_pairs.npy")
angle = angles[4]
mask_fracs = [0.1, 0.3, 0.6, 0.9]

fig, ax = plt.subplots(1,4, figsize=(10,4))
for i, mask_frac in enumerate(mask_fracs):
    I = sta_validate.make_phantom(x, angle, period=7, mask_frac=mask_frac, inverse=False)
    ax[i].imshow(I)
    ax[i].set_title(f"{int(mask_frac*100)}%")
    ax[i].axis("off")
plt.tight_layout()
fig.savefig('../outputs/figures/2d_phantoms_mask_fractions.png')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
n = (32,96)
d = (n[1]/n[0], 1.0)
x = [np.arange(ni)*di for ni,di in zip(n,d)]
periods = (7,10,13)
angle_pairs = np.load("../theta_pairs.npy")
root = "/home/brysongray/bmap/fibermetric/st_validation/phantoms_2d_var_mask-frac/"
mask_fracs = np.linspace(0.0, 0.9, 10)
for j,k,n in tqdm_itertools.product(range(len(periods)), range(len(angle_pairs)), range(len(mask_fracs))):
        p = periods[j]
        angle_pair = angle_pairs[k]
        mask_frac = mask_fracs[n]
        # image = sta_validate.make_phantom(x,[angle], p)
        image = sta_validate.make_phantom(x, angle_pair, p, inverse=False, mask_frac=mask_frac)

        # save image
        name = f'phantom_AI-{d[0]:.2f}_period-{p:02d}_theta-{angle_pair[0]:.2f}-{angle_pair[1]:.2f}_mask_frac-{mask_frac:.1f}'
        print(f'saving {root+name}')
        np.savez(join(root,name), image=image, AI=d[0], period=p, angle=angle_pair, mask_frac=mask_frac)
# Out:
#   0%|          | 0/3000 [00:00<?, ?it/s]
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_2d_var_mask-frac/phantom_AI-3.00_period-07_theta-1.03-1.33_mask_frac-0.0
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_2d_var_mask-frac/phantom_AI-3.00_period-07_theta-1.03-1.33_mask_frac-0.1
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_2d_var_mask-frac/phantom_AI-3.00_period-07_theta-1.03-1.33_mask_frac-0.2
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_2d_var_mask-frac/phantom_AI-3.00_period-07_theta-1.03-1.33_mask_frac-0.3
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_2d_var_mask-frac/phantom_AI-3.00_period-07_theta-1.03-1.33_mask_frac-0.4
# saving /home/brysongray/bmap/fibermetric/st_validation/phantoms_2d_var_mask-frac/phantom_AI-3.00_period-07_theta-1.03-1.33_mask_frac-0.5
# ...
