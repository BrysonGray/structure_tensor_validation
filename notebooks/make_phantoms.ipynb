# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %%
from os import listdir
from os.path import join
import os
import matplotlib.pyplot as plt
from dipy.core.sphere import disperse_charges, HemiSphere
import numpy as np
import pandas as pd
import cProfile
from tqdm import tqdm
from tqdm.contrib import itertools as tqdm_itertools
from scipy.ndimage import gaussian_filter

import sys
sys.path.insert(0,'../st_validate/')
import sta_validate
import histology
import apsym_kmeans

# %% [markdown]
# ## set parameters for 3D phantoms

# %%
shapes = [(72,72,72), (36,72,72), (24,72,72), (18,72,72), (14,72,72), (12,72,72), (10,72,72), (9,72,72)]
anisotropy_ratio = [d[1]/d[0] for d in shapes]
periods = [7,10,13]
angles = np.load('../3d_angles.npy')
root = '../outputs/phantoms/'
os.makedirs(root, exist_ok=True)

# %%
angles.shape
# Out:
# (100, 2)

# %%
# get angles evenly distributed over a hemisphere

n_pts = 100
theta = np.pi - np.random.rand(n_pts)
phi = 2 * np.pi - np.random.rand(n_pts)
v_initial = HemiSphere(theta=theta, phi=phi)
v_updated, potential = disperse_charges(v_initial, 20000, const=0.1)
vertices = v_updated.vertices
plt.plot(potential)
plt.show()
angles = np.array([np.arccos(vertices[:,0]), np.arctan2(vertices[:,2],vertices[:,1])]).T


# thetas = np.linspace(0,np.pi/2,5)
# phis = np.linspace(0, np.pi/2, 5)
# angles = np.empty((5,5,2))
# for i in range(len(thetas)):
#     for j in range(len(phis)):
#         angles[i,j] = [thetas[i], phis[-(j+1)]]
# angles = angles.reshape(-1,2)[4:]
# print(angles)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# this should give us close to 25 points per quadrant if it's distributed uniformly. 
octant0 = [a for a in angles if np.all(a <= np.pi/2) and np.all(a >= 0.0)]
print(len(octant0))
octant1 = [a for a in angles if a[0] <= np.pi/2 and a[1] >= np.pi/2]
print(len(octant1))
octant2 = [a for a in angles if a[0] >= np.pi/2 and a[1] <= np.pi/2]
print(len(octant2))
octant3 = [a for a in angles if a[0] >= np.pi/2 and a[1] >= np.pi/2]
print(len(octant3))
print(np.std(np.array([len(octant0),len(octant1),len(octant2),len(octant3)])))
print(len(angles))
print(potential[-1])
# np.save('../outputs/sta_validate_outputs/angles.npy', angles)

# %%
angles[0]
# Out:
# array([0.83244322, 3.11407247])

# %%
for i in tqdm(range(len(shapes))):
    n = shapes[i]
    d = (n[1]/n[0], 1.0, 1.0)
    x = [np.arange(ni)*di for ni,di in zip(n,d)]

    for j,k in tqdm_itertools.product(range(len(periods)), range(len(angles))):
            p = periods[j]
            angle = angles[k]
            # image = sta_validate.make_phantom(x,[angle], p)
            image = sta_validate.make_phantom(x,[angle], p, inverse=True)

            # save image
            name = f'phantom_AI-{d[0]:.2f}_period-{p:02d}_theta-{angle[0]:.2f}_phi-{angle[1]:.2f}'
            print(f'saving {root+name}')
            np.savez(join(root,name), image=image, AI=d[0], period=p, angle=angle)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.83_phi-3.11
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.22_phi-1.26
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.43_phi-1.14
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.89_phi-0.33
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.54_phi-2.74
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.01_phi-2.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.97_phi-2.85
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.41_phi-2.88
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.63_phi-3.03
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.31_phi-0.20
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.76_phi-2.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.02_phi-1.11
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.88_phi-0.40
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.95_phi-0.78
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.34_phi-0.78
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.75_phi-2.51
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.57_phi-0.56
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.53_phi-2.01
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.27_phi-2.33
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.78_phi-1.58
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.61_phi-1.38
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.42_phi-0.78
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.59_phi-0.29
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.81_phi-1.63
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.47_phi-0.91
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.69_phi-2.15
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.81_phi-0.07
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.79_phi-0.87
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.54_phi-0.07
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.08_phi-1.77
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.11_phi-1.35
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.03_phi-1.43
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.35_phi-0.37
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.19_phi-1.14
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.04_phi-2.23
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.97_phi-2.38
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.03_phi-0.64
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.29_phi-2.44
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.54_phi-1.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.14_phi-2.13
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.34_phi-1.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.98_phi-2.84
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.87_phi-1.62
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.60_phi-0.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.75_phi-1.85
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.59_phi-1.63
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.18_phi-0.42
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.09_phi-1.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.13_phi-0.55
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.88_phi-0.62
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.80_phi-0.08
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.14_phi-3.03
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.21_phi-0.93
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.68_phi-0.44
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.55_phi-2.39
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.30_phi-1.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.37_phi-2.57
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.60_phi-0.17
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.82_phi-2.38
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.08_phi-0.84
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.65_phi-2.92
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.10_phi-0.16
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.36_phi-1.47
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.07_phi-2.54
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.84_phi-1.35
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.98_phi-1.95
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.68_phi-1.10
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.28_phi-2.35
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.33_phi-1.71
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.73_phi-2.30
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.31_phi-1.89
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.22_phi-2.79
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.77_phi-2.76
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.44_phi-2.15
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.91_phi-2.29
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.57_phi-1.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.44_phi-1.17
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.50_phi-2.49
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.51_phi-1.90
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.74_phi-2.02
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.39_phi-2.97
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.12_phi-0.22
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.53_phi-2.75
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.67_phi-0.99
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.08_phi-1.42
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.94_phi-1.10
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.37_phi-0.23
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.24_phi-1.98
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.79_phi-1.25
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.68_phi-0.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.53_phi-2.24
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.79_phi-0.15
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-2.21_phi-2.68
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.11_phi-3.09
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.57_phi-1.17
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.44_phi-0.49
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.84_phi-3.11
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-0.88_phi-0.87
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.93_phi-2.01
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-07_theta-1.29_phi-0.69
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.83_phi-3.11
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.22_phi-1.26
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.43_phi-1.14
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.89_phi-0.33
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.54_phi-2.74
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.01_phi-2.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.97_phi-2.85
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.41_phi-2.88
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.63_phi-3.03
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.31_phi-0.20
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.76_phi-2.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.02_phi-1.11
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.88_phi-0.40
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.95_phi-0.78
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.34_phi-0.78
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.75_phi-2.51
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.57_phi-0.56
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.53_phi-2.01
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.27_phi-2.33
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.78_phi-1.58
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.61_phi-1.38
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.42_phi-0.78
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.59_phi-0.29
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.81_phi-1.63
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.47_phi-0.91
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.69_phi-2.15
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.81_phi-0.07
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.79_phi-0.87
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.54_phi-0.07
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.08_phi-1.77
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.11_phi-1.35
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.03_phi-1.43
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.35_phi-0.37
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.19_phi-1.14
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.04_phi-2.23
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.97_phi-2.38
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.03_phi-0.64
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.29_phi-2.44
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.54_phi-1.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.14_phi-2.13
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.34_phi-1.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.98_phi-2.84
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.87_phi-1.62
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.60_phi-0.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.75_phi-1.85
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.59_phi-1.63
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.18_phi-0.42
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.09_phi-1.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.13_phi-0.55
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.88_phi-0.62
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.80_phi-0.08
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.14_phi-3.03
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.21_phi-0.93
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.68_phi-0.44
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.55_phi-2.39
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.30_phi-1.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.37_phi-2.57
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.60_phi-0.17
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.82_phi-2.38
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.08_phi-0.84
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.65_phi-2.92
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.10_phi-0.16
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.36_phi-1.47
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.07_phi-2.54
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.84_phi-1.35
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.98_phi-1.95
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.68_phi-1.10
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.28_phi-2.35
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.33_phi-1.71
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.73_phi-2.30
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.31_phi-1.89
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.22_phi-2.79
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.77_phi-2.76
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.44_phi-2.15
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.91_phi-2.29
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.57_phi-1.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.44_phi-1.17
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.50_phi-2.49
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.51_phi-1.90
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.74_phi-2.02
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.39_phi-2.97
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.12_phi-0.22
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.53_phi-2.75
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.67_phi-0.99
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.08_phi-1.42
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.94_phi-1.10
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.37_phi-0.23
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.24_phi-1.98
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.79_phi-1.25
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.68_phi-0.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.53_phi-2.24
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.79_phi-0.15
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-2.21_phi-2.68
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.11_phi-3.09
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.57_phi-1.17
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.44_phi-0.49
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.84_phi-3.11
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-0.88_phi-0.87
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.93_phi-2.01
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-10_theta-1.29_phi-0.69
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.83_phi-3.11
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.22_phi-1.26
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.43_phi-1.14
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.89_phi-0.33
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.54_phi-2.74
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.01_phi-2.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.97_phi-2.85
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.41_phi-2.88
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.63_phi-3.03
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.31_phi-0.20
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.76_phi-2.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.02_phi-1.11
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.88_phi-0.40
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.95_phi-0.78
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.34_phi-0.78
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.75_phi-2.51
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.57_phi-0.56
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.53_phi-2.01
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.27_phi-2.33
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.78_phi-1.58
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.61_phi-1.38
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.42_phi-0.78
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.59_phi-0.29
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.81_phi-1.63
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.47_phi-0.91
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.69_phi-2.15
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.81_phi-0.07
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.79_phi-0.87
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.54_phi-0.07
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.08_phi-1.77
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.11_phi-1.35
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.03_phi-1.43
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.35_phi-0.37
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.19_phi-1.14
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.04_phi-2.23
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.97_phi-2.38
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.03_phi-0.64
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.29_phi-2.44
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.54_phi-1.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.14_phi-2.13
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.34_phi-1.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.98_phi-2.84
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.87_phi-1.62
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.60_phi-0.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.75_phi-1.85
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.59_phi-1.63
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.18_phi-0.42
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.09_phi-1.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.13_phi-0.55
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.88_phi-0.62
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.80_phi-0.08
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.14_phi-3.03
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.21_phi-0.93
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.68_phi-0.44
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.55_phi-2.39
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.30_phi-1.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.37_phi-2.57
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.60_phi-0.17
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.82_phi-2.38
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.08_phi-0.84
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.65_phi-2.92
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.10_phi-0.16
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.36_phi-1.47
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.07_phi-2.54
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.84_phi-1.35
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.98_phi-1.95
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.68_phi-1.10
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.28_phi-2.35
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.33_phi-1.71
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.73_phi-2.30
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.31_phi-1.89
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.22_phi-2.79
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.77_phi-2.76
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.44_phi-2.15
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.91_phi-2.29
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.57_phi-1.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.44_phi-1.17
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.50_phi-2.49
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.51_phi-1.90
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.74_phi-2.02
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.39_phi-2.97
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.12_phi-0.22
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.53_phi-2.75
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.67_phi-0.99
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.08_phi-1.42
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.94_phi-1.10
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.37_phi-0.23
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.24_phi-1.98
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.79_phi-1.25
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.68_phi-0.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.53_phi-2.24
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.79_phi-0.15
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-2.21_phi-2.68
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.11_phi-3.09
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.57_phi-1.17
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.44_phi-0.49
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.84_phi-3.11
#  12%|█▎        | 1/8 [00:21<02:31, 21.61s/it]
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-0.88_phi-0.87
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.93_phi-2.01
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-1.00_period-13_theta-1.29_phi-0.69
#   0%|          | 0/300 [00:00<?, ?it/s]
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.83_phi-3.11
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.22_phi-1.26
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.43_phi-1.14
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.89_phi-0.33
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.54_phi-2.74
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.01_phi-2.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.97_phi-2.85
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.41_phi-2.88
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.63_phi-3.03
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.31_phi-0.20
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.76_phi-2.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.02_phi-1.11
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.88_phi-0.40
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.95_phi-0.78
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.34_phi-0.78
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.75_phi-2.51
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.57_phi-0.56
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.53_phi-2.01
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.27_phi-2.33
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.78_phi-1.58
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.61_phi-1.38
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.42_phi-0.78
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.59_phi-0.29
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.81_phi-1.63
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.47_phi-0.91
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.69_phi-2.15
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.81_phi-0.07
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.79_phi-0.87
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.54_phi-0.07
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.08_phi-1.77
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.11_phi-1.35
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.03_phi-1.43
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.35_phi-0.37
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.19_phi-1.14
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.04_phi-2.23
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.97_phi-2.38
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.03_phi-0.64
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.29_phi-2.44
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.54_phi-1.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.14_phi-2.13
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.34_phi-1.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.98_phi-2.84
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.87_phi-1.62
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.60_phi-0.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.75_phi-1.85
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.59_phi-1.63
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.18_phi-0.42
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.09_phi-1.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.13_phi-0.55
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.88_phi-0.62
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.80_phi-0.08
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.14_phi-3.03
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.21_phi-0.93
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.68_phi-0.44
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.55_phi-2.39
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.30_phi-1.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.37_phi-2.57
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.60_phi-0.17
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.82_phi-2.38
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.08_phi-0.84
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.65_phi-2.92
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.10_phi-0.16
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.36_phi-1.47
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.07_phi-2.54
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.84_phi-1.35
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.98_phi-1.95
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.68_phi-1.10
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.28_phi-2.35
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.33_phi-1.71
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.73_phi-2.30
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.31_phi-1.89
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.22_phi-2.79
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.77_phi-2.76
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.44_phi-2.15
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.91_phi-2.29
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.57_phi-1.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.44_phi-1.17
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.50_phi-2.49
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.51_phi-1.90
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.74_phi-2.02
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.39_phi-2.97
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.12_phi-0.22
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.53_phi-2.75
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.67_phi-0.99
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.08_phi-1.42
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.94_phi-1.10
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.37_phi-0.23
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.24_phi-1.98
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.79_phi-1.25
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.68_phi-0.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.53_phi-2.24
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.79_phi-0.15
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-2.21_phi-2.68
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.11_phi-3.09
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.57_phi-1.17
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.44_phi-0.49
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.84_phi-3.11
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-0.88_phi-0.87
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.93_phi-2.01
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-07_theta-1.29_phi-0.69
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-0.83_phi-3.11
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-1.22_phi-1.26
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-2.43_phi-1.14
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-1.89_phi-0.33
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-1.54_phi-2.74
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-2.01_phi-2.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-1.97_phi-2.85
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-2.41_phi-2.88
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-1.63_phi-3.03
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-0.31_phi-0.20
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-0.76_phi-2.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-1.02_phi-1.11
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-0.88_phi-0.40
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-2.95_phi-0.78
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-2.34_phi-0.78
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-1.75_phi-2.51
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-2.57_phi-0.56
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-2.53_phi-2.01
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-1.27_phi-2.33
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-2.78_phi-1.58
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-1.61_phi-1.38
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-0.42_phi-0.78
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-0.59_phi-0.29
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-0.81_phi-1.63
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-1.47_phi-0.91
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-1.69_phi-2.15
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-1.81_phi-0.07
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-1.79_phi-0.87
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-2.54_phi-0.07
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-2.08_phi-1.77
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-0.11_phi-1.35
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-1.03_phi-1.43
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-2.35_phi-0.37
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-2.19_phi-1.14
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-1.04_phi-2.23
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-2.97_phi-2.38
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-1.03_phi-0.64
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-2.00_period-10_theta-0.29_phi-2.44
# ...
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.55_phi-2.39
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-2.30_phi-1.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.37_phi-2.57
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.60_phi-0.17
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-0.82_phi-2.38
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-2.08_phi-0.84
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-2.65_phi-2.92
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.10_phi-0.16
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.36_phi-1.47
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.07_phi-2.54
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.84_phi-1.35
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-0.98_phi-1.95
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.68_phi-1.10
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-2.28_phi-2.35
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.33_phi-1.71
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-2.73_phi-2.30
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-2.31_phi-1.89
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.22_phi-2.79
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.77_phi-2.76
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.44_phi-2.15
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.91_phi-2.29
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-0.57_phi-1.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.44_phi-1.17
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-2.50_phi-2.49
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.51_phi-1.90
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-0.74_phi-2.02
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.39_phi-2.97
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-2.12_phi-0.22
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-0.53_phi-2.75
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-2.67_phi-0.99
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-2.08_phi-1.42
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.94_phi-1.10
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.37_phi-0.23
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.24_phi-1.98
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-0.79_phi-1.25
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-0.68_phi-0.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-0.53_phi-2.24
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-2.79_phi-0.15
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-2.21_phi-2.68
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.11_phi-3.09
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-0.57_phi-1.17
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.44_phi-0.49
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.84_phi-3.11
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-0.88_phi-0.87
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.93_phi-2.01
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-10_theta-1.29_phi-0.69
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.83_phi-3.11
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.22_phi-1.26
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.43_phi-1.14
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.89_phi-0.33
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.54_phi-2.74
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.01_phi-2.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.97_phi-2.85
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.41_phi-2.88
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.63_phi-3.03
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.31_phi-0.20
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.76_phi-2.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.02_phi-1.11
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.88_phi-0.40
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.95_phi-0.78
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.34_phi-0.78
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.75_phi-2.51
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.57_phi-0.56
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.53_phi-2.01
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.27_phi-2.33
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.78_phi-1.58
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.61_phi-1.38
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.42_phi-0.78
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.59_phi-0.29
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.81_phi-1.63
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.47_phi-0.91
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.69_phi-2.15
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.81_phi-0.07
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.79_phi-0.87
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.54_phi-0.07
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.08_phi-1.77
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.11_phi-1.35
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.03_phi-1.43
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.35_phi-0.37
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.19_phi-1.14
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.04_phi-2.23
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.97_phi-2.38
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.03_phi-0.64
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.29_phi-2.44
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.54_phi-1.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.14_phi-2.13
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.34_phi-1.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.98_phi-2.84
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.87_phi-1.62
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.60_phi-0.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.75_phi-1.85
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.59_phi-1.63
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.18_phi-0.42
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.09_phi-1.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.13_phi-0.55
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.88_phi-0.62
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.80_phi-0.08
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.14_phi-3.03
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.21_phi-0.93
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.68_phi-0.44
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.55_phi-2.39
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.30_phi-1.53
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.37_phi-2.57
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.60_phi-0.17
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.82_phi-2.38
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.08_phi-0.84
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.65_phi-2.92
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.10_phi-0.16
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.36_phi-1.47
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.07_phi-2.54
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.84_phi-1.35
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.98_phi-1.95
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.68_phi-1.10
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.28_phi-2.35
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.33_phi-1.71
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.73_phi-2.30
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.31_phi-1.89
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.22_phi-2.79
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.77_phi-2.76
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.44_phi-2.15
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.91_phi-2.29
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.57_phi-1.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.44_phi-1.17
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.50_phi-2.49
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.51_phi-1.90
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.74_phi-2.02
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.39_phi-2.97
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.12_phi-0.22
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.53_phi-2.75
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.67_phi-0.99
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.08_phi-1.42
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.94_phi-1.10
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.37_phi-0.23
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.24_phi-1.98
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.79_phi-1.25
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.68_phi-0.70
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.53_phi-2.24
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.79_phi-0.15
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-2.21_phi-2.68
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.11_phi-3.09
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.57_phi-1.17
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.44_phi-0.49
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.84_phi-3.11
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-0.88_phi-0.87
# 100%|██████████| 8/8 [02:44<00:00, 20.52s/it]
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.93_phi-2.01
# saving ../outputs/sta_validate_outputs/phantoms/phantoms-72-BF/phantom_AI-8.00_period-13_theta-1.29_phi-0.69

# %% [markdown]
# ## Add images for two angle phantoms

# %% [markdown]
# ### first get all pair combinations. (n_angles choose 2 pairs) then choose a random subset of 100

# %%
angle_pairs = [(a, b, a_idx, b_idx + a_idx + 1) for a_idx, a in enumerate(angles) for b_idx, b in enumerate(angles[a_idx+1:])]
angle_pair_ids = np.array([a[2:] for a in angle_pairs])
angle_pairs = np.array([a[:2] for a in angle_pairs])

ids = np.random.choice(len(angle_pairs), size=100, replace=False)

angle_pairs = angle_pairs[ids]
angle_pair_ids = angle_pair_ids[ids]
print(angle_pairs.shape)
print(angle_pair_ids.shape)

# %% [markdown]
# ## how are delta angles distributed?

# %%
direction_pairs = np.array([np.cos(angle_pairs[:,:,0]),
                            np.sin(angle_pairs[:,:,0])*np.cos(angle_pairs[:,:,1]),
                            np.sin(angle_pairs[:,:,0])*np.sin(angle_pairs[:,:,1])]).transpose(1,2,0)
print(direction_pairs.shape)

deltas = np.arccos(np.abs((direction_pairs[:,None,0] @ direction_pairs[:,1,...,None])[:,0,0]))

print(f'deltas min: {deltas.min()}, max: {deltas.max()}')
plt.hist(deltas)
plt.plot(np.ones(100)*np.mean(deltas), np.linspace(0,20,100), label='mean')
plt.plot(np.ones(100)*np.pi/4, np.linspace(0,20,100), label='center')
plt.legend()
plt.show()

# %%
# np.save('../outputs/sta_validate_outputs/angle_pairs', angle_pairs)

# %% [markdown]
# ## save two angle phantoms

# %%
angle_pairs = np.load('../outputs/sta_validate_outputs/angle_pairs.npy')

# %%
for i,d in enumerate(AI):
    n = shapes[i]
    dx = (n[1]/n[0], 1.0, 1.0)
    x = [np.arange(ni)*di for ni,di in zip(n,dx)]
    for p in periods:
        for a in angle_pairs:
            # img = sta_validate.make_phantom(x, a, p)
            img = sta_validate.make_phantom(x, a, p, inverse=True)

            name = f'phantom_AI-{d:.2f}_period-{p:02d}_theta-{a[0,0]:.2f}-{a[1,0]:.2f}_phi-{a[0,1]:.2f}-{a[1,1]:.2f}'
            np.savez(join(root,name), image=img, AI=d, period=p, angle=a)

# %%
for d in AI:
    for p in periods:
        for a in angle_pairs:
            files = listdir(root)
            I_file = [f for f in files if f.split('theta-')[1][:4]==f'{a[0,0]:.2f}' and f.split('phi-')[1][:4]==f'{a[0,1]:.2f}' and f.split('AI-')[1][:4]==f'{d:.2f}' and f.split('period-')[1][:2]==f'{p:02d}'][0]
            J_file = [f for f in files if f.split('theta-')[1][:4]==f'{a[1,0]:.2f}' and f.split('phi-')[1][:4]==f'{a[1,1]:.2f}' and f.split('AI-')[1][:4]==f'{d:.2f}' and f.split('period-')[1][:2]==f'{p:02d}'][0]
            I = np.load(join(root,I_file))['image']
            J = np.load(join(root,J_file))['image']
            new_phantom = I + J
            name = f'phantom_AI-{d:.2f}_period-{p:02d}_theta-{a[0,0]:.2f}-{a[1,0]:.2f}_phi-{a[0,1]:.2f}-{a[1,1]:.2f}'
            np.savez(join(root,name), image=new_phantom, AI=d, period=p, angle=a)

# %% [markdown]
# ## Make phantoms with isotropic blur

# %%
# add isotropic blur to phantoms
out = '../outputs/sta_validate_outputs/phantoms/phantoms-72-iso-blur/'
files = listdir(root)
for f in tqdm(files):
    npz = np.load(join(root,f))
    image = npz['image']
    AI = npz['AI']
    period = npz['period']
    angle = npz['angle']
    dI = [float(AI), 1.0, 1.0]
    blur_factor = np.sqrt(dI[0]**2 - 1.0)
    new_image = gaussian_filter(image, sigma=[0.0, blur_factor, blur_factor])
    if angle.ndim == 1:
        name = f'phantom_AI-{AI:.2f}_period-{period:02d}_theta-{angle[0]:.2f}_phi-{angle[1]:.2f}'
    else:
        name = f'phantom_AI-{AI:.2f}_period-{period:02d}_theta-{angle[0,0]:.2f}-{angle[1,0]:.2f}_phi-{angle[0,1]:.2f}-{angle[1,1]:.2f}'
    np.savez(join(out,name), image=new_image, AI=AI, period=period, angle=angle)
# Out:
#   0%|          | 0/4800 [00:00<?, ?it/s]
# 100%|██████████| 4800/4800 [01:10<00:00, 68.38it/s]

# %% [markdown]
# # 2D Phantoms

# %% [markdown]
# ## Set Parameters

# %%
shapes = [(96,96), (48,96), (32,96), (24,96), (19,96), (16,96), (14,96), (12,96)]
AI = [d[1]/d[0] for d in shapes]
periods = [7,10,13]
thetas = np.linspace(0,np.pi/2,100)

root = '../outputs/sta_validate_outputs/phantoms/phantoms_2d-96-BF/'
os.makedirs(root, exist_ok=True)

# %%
theta_pairs = [(a, b) for idx, a in enumerate(thetas) for b in thetas[idx+1:]]
ids = np.random.choice(len(theta_pairs), size=100, replace=False)
theta_pairs = np.array(theta_pairs)[ids]
# np.save('../outputs/sta_validate_outputs/theta_pairs', theta_pairs)

# %%
for i in tqdm(range(len(shapes))):
    n = shapes[i]
    d = (n[1]/n[0], 1.0)
    x = [np.arange(ni)*di for ni,di in zip(n,d)]

    for j,k in tqdm_itertools.product(range(len(periods)), range(len(thetas))):
            p = periods[j]
            angle = thetas[k]
            # image = sta_validate.make_phantom(x,[angle], p)
            image = sta_validate.make_phantom(x,[angle], p, inverse=False)
            # save image
            # name = f'phantom_AI-{d[0]:.2f}_period-{p:02d}_theta-{angle:.2f}'
            # print(f'saving {root+name}')
            # np.savez(join(root,name), image=image, AI=d[0], period=p, angle=angle)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#  12%|█▎        | 1/8 [2:09:16<15:04:55, 7756.52s/it]
#   0%|          | 0/300 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [2:09:16<5:19:24, 3194.03s/it]
#   0%|          | 0/300 [00:00<?, ?it/s]
#  38%|███▊      | 3/8 [2:09:17<2:24:38, 1735.70s/it]
#   0%|          | 0/300 [00:00<?, ?it/s]
#  50%|█████     | 4/8 [2:09:17<1:10:02, 1050.57s/it]
#   0%|          | 0/300 [00:00<?, ?it/s]
#  62%|██████▎   | 5/8 [2:09:17<33:35, 671.82s/it]
#   0%|          | 0/300 [00:00<?, ?it/s]
#  75%|███████▌  | 6/8 [2:09:17<14:46, 443.48s/it]
#   0%|          | 0/300 [00:00<?, ?it/s]
#  88%|████████▊ | 7/8 [2:09:18<04:58, 298.58s/it]
#   0%|          | 0/300 [00:00<?, ?it/s]
# 100%|██████████| 8/8 [2:09:18<00:00, 969.79s/it]

# %%
theta_pairs = np.load('../outputs/sta_validate_outputs/theta_pairs.npy')
for i in tqdm(range(len(shapes))):
    n = shapes[i]
    d = (n[1]/n[0], 1.0)
    x = [np.arange(ni)*di for ni,di in zip(n,d)]

    for j,k in tqdm_itertools.product(range(len(periods)), range(len(theta_pairs))):
            p = periods[j]
            angle = theta_pairs[k]
            # image = sta_validate.make_phantom(x,angle, p)
            image = sta_validate.make_phantom(x,angle, p, inverse=True)

            # save image
            name = f'phantom_AI-{d[0]:.2f}_period-{p:02d}_theta-{angle[0]:.2f}-{angle[1]:.2f}'
            # print(f'saving {root+name}')
            np.savez(join(root,name), image=image, AI=d[0], period=p, angle=angle)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#  12%|█▎        | 1/8 [00:00<00:02,  3.17it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:02,  2.77it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#  38%|███▊      | 3/8 [00:01<00:01,  2.76it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#  50%|█████     | 4/8 [00:01<00:01,  2.79it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#  62%|██████▎   | 5/8 [00:01<00:01,  2.80it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#  75%|███████▌  | 6/8 [00:02<00:00,  2.84it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
#  88%|████████▊ | 7/8 [00:02<00:00,  2.91it/s]
#   0%|          | 0/300 [00:00<?, ?it/s]
# 100%|██████████| 8/8 [00:02<00:00,  2.87it/s]

# %%
len(files)
# Out:
# 4800

# %%
# add isotropic blur to phantoms
out = '../outputs/sta_validate_outputs/phantoms/phantoms_2d-96-iso-blur/'
files = listdir(root)
for f in tqdm(files):
    npz = np.load(join(root,f))
    image = npz['image']
    AI = npz['AI']
    period = npz['period']
    angle = npz['angle']
    blur_factor = np.sqrt(float(AI)**2 - 1.0)
    new_image = gaussian_filter(image, sigma=[0., blur_factor])
    if angle.ndim == 0:
        name = f'phantom_AI-{AI:.2f}_period-{period:02d}_theta-{angle:.2f}'
    else:
        name = f'phantom_AI-{AI:.2f}_period-{period:02d}_theta-{angle[0]:.2f}-{angle[1]:.2f}'
    np.savez(join(out,name), image=new_image, AI=AI, period=period, angle=angle)
# Out:
# 100%|██████████| 4800/4800 [00:05<00:00, 826.35it/s]

# %% [markdown]
# # Structure Tensor Analysis on premade phantoms

# %%
derivative_sigmas = np.linspace(start=0.15, stop=2.5, num=10)
tensor_sigmas = np.linspace(start=0.0, stop=10.0, num=10)
print(derivative_sigmas)
print(tensor_sigmas)
print(thetas)

# %%
# name = root+'phantom_AI-1.00_period-8_theta-0.00-0.39_phi-0.00.npy'
name = root+'phantom_AI-1.00_period-12_theta-0.00-1.57_phi-0.00.npy'
phantom = np.load(name)
d = 2
t = 1
with cProfile.Profile() as pr:
    error = sta_validate.sta_test(phantom, derivative_sigmas[d], tensor_sigmas[t], true_thetas=[(0.0,0.0), (thetas[4],0.0)])
    print(error)/home/brysongray
    pr.print_stats(sort='tottime')

# %%
fig,ax = plt.subplots(3)
ax[0].imshow(phantom[36,:,:])
ax[1].imshow(phantom[:,36,:])
ax[2].imshow(phantom[:,:,36])

# %%
phi1_phantoms = [f for f in listdir(root) if f.split('phi-')[1][:4]=='0.39']
print(len(phi1_phantoms))

# %%
# run structure tensor analysis for every phantom
# I need to get the actual parameter values given the rounded values in the file name
error_df = pd.DataFrame({'derivative_sigma':[], 'tensor_sigma':[], 'AI':[], 'period':[],
                         'width':[], 'angles':[], 'error':[]})
d = np.array([n[1]/n[0] for n in shapes])
for f in listdir(root):
    AI_ = float(f.split('AI-')[1][:4])
    AI = d[np.argmin(np.abs(d - AI_))]
    period = int(f.split('period-')[1][:2])
    phi_ = float(f.split('phi-')[1][:4])
    phi = phis[np.argmin(np.abs(phis - phi_))]
    theta_ = f.split('theta-')[1][:9].split('-')
    if len(theta_[1]) == 0:
        theta = thetas[np.argmin(np.abs(thetas - float(theta_[0][:4])))]
        angles = [(theta, phi)]
    else:
        theta = [thetas[np.argmin(np.abs(thetas - float(theta_[0][:4])))],
                  thetas[np.argmin(np.abs(thetas - float(theta_[1][:4])))]]
        angles = [(theta[0], phi), (theta[1], phi)]
    
    # phantom = np.load(root+f)
    for sigma0 in derivative_sigmas:
        for sigma1 in tensor_sigmas:
            # error = sta_validate.sta_test(phantom, sigma0, sigma1, true_thetas=angles)
            new_row = {'derivative_sigma': sigma0, 'tensor_sigma': sigma1, 'AI': AI, 'period': period, 'width': 1, 'angles': [angles], 'error': 0}
            error_df = pd.concat([error_df, pd.DataFrame(new_row)], ignore_index=True)

# %%
# 2d
root = '../outputs/sta_validate_outputs/phantoms/phantoms_2d-96/'
files = os.listdir(root)
# one angle
# file = files[0]
# two angles
file = files[2]

# # 3d
# root = '../outputs/sta_validate_outputs/phantoms/phantoms-72_v2/'
# files = os.listdir(root)
# # one angle
# file = files[3]
# # two angles
# # file = files[0]

# print(file)
# # npz = np.load(join(root, files[3]))
# npz = np.load(join(root, file))
# phantom = npz['image']
# AI = npz['AI']
# period = npz['period']
# angle = npz['angle']
# # angle = np.array([angle])
# print(angle)
# error_df = pd.DataFrame({'derivative_sigma':[], 'tensor_sigma':[], 'AI':[], 'period':[],
#                         'width':[], 'angles':[], 'error':[]})
# sigma0 = 1.0
# sigma1 = 1.0
# error = sta_validate.sta_test(phantom, derivative_sigma=sigma0, tensor_sigma=sigma1, true_thetas=angle, crop=12)

# new_row = {'derivative_sigma': sigma0, 'tensor_sigma': sigma1,
#                         'AI': AI, 'period': period, 'width': 1,
#                         'angles': [angle], 'error': error}
# error_df = pd.concat((error_df, pd.DataFrame(new_row)), ignore_index=True)

# # save dataframe using pickle
# if phantom.ndim == 2:
#     if angle.ndim == 0:
#         name = f'error_AI-{AI:.2f}_period-{period:02d}_theta-{angle:.2f}.p'
#     else:
#         name = f'error_AI-{AI:.2f}_period-{period:02d}_theta-{angle[0]:.2f}-{angle[1]:.2f}.p'

# if phantom.ndim == 3:
#     if angle.ndim == 1:
#             name = f'error_AI-{AI:.2f}_period-{period:02d}_theta-{angle[0]:.2f}_phi-{angle[1]:.2f}.p'
#     else:
#         name = f'error_AI-{AI:.2f}_period-{period:02d}_theta-{angle[0,0]:.2f}-{angle[1,0]:.2f}_phi-{angle[0,1]:.2f}-{angle[1,1]:.2f}.p'

# print(f'saving {name}')

# %%
plt.close('all')

# %%
i = 0
n = shapes[i]
d = (n[1]/n[0], 1.0)
x = [np.arange(ni)*di for ni,di in zip(n,d)]
angle = thetas[30]
p = periods[1]
# image = sta_validate.make_phantom(x,angle, p, inverse=True)
image = sta_validate.make_phantom(x,[angle], p, inverse=True)

plt.figure()
plt.imshow(image, cmap='gray')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# root = '/home/brysongray/fibermetric/outputs/sta_validate_outputs/phantoms/phantoms-72-BF/'
root = '/home/brysongray/fibermetric/outputs/sta_validate_outputs/phantoms/phantoms_2d-96-BF/'
phantoms_2d_BF = os.listdir(root)
# p_ = np.load(os.path.join(root,phantoms_3d_BF[9]))
p_ = np.load(os.path.join(root,phantoms_2d_BF[15]))
plt.figure()
plt.imshow(p_['image'], cmap='gray')
# plt.imshow(p_['image'][36,:,:], cmap='gray')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sigma0 = 1.0
sigma1 = 5.0
S = histology.structure_tensor(img, derivative_sigma=sigma0, tensor_sigma=sigma1, dI=d, masked=False)
angles = histology.angles(S, cartesian=True)
fig, ax = plt.subplots(1,3)
ax[0].imshow(angles[...,36,0], cmap='hsv')
ax[1].imshow(angles[...,36,1], cmap='hsv')
ax[2].imshow(angles[...,36,2], cmap='hsv')

# %%
# convert true_thetas to cartesian coordinates for easier error calculation
true_thetas = np.array(thetas)
if true_thetas.ndim == 1:
    true_thetas = np.array([np.sin(true_thetas[0])*np.sin(true_thetas[1]),
                                    np.sin(true_thetas[0])*np.cos(true_thetas[1]),
                                    np.cos(true_thetas[0])
                                    ])
    skm = apsym_kmeans.APSymKMeans(n_clusters=1)
elif true_thetas.ndim == 2:
    true_thetas = np.array([np.sin(true_thetas[:,0])*np.sin(true_thetas[:,1]),
                                    np.sin(true_thetas[:,0])*np.cos(true_thetas[:,1]),
                                    np.cos(true_thetas[:,0])
                                    ]).T
    skm = apsym_kmeans.APSymKMeans(n_clusters=2)

angles_ = angles.reshape(-1,3)
skm.fit(angles_)
mu_ = skm.cluster_centers_

# %%
print(mu_)
diff = np.arccos(np.abs(mu_.dot(true_thetas))) * 180/np.pi 
print(diff)

# %%
error = sta_validate.sta_test(img, sigma0, sigma1, true_thetas=thetas, crop=12)

# %%
error
